# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('titanic.csv')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
# age
sns.distplot(data.age)
# Out:
# <ipython-input-8-066c467e89b1>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.age)
# <Axes: xlabel='age', ylabel='Density'>

# %%
#age
plt.hist(data['age'])
plt.xlabel('age')
plt.ylabel('frequency')
plt.title('Age group')
# Out:
# Text(0.5, 1.0, 'Age group')

# %%
#sex group
plt.hist(data['sex'])
plt.xlabel('sex')
plt.ylabel('frequency')
plt.title('Sex group')
# Out:
# Text(0.5, 1.0, 'Sex group')

# %%
#class group
plt.bar(data['class'],data['age'])
plt.xlabel('class')
plt.ylabel('frequency')
plt.title('Class group')
# Out:
# Text(0.5, 1.0, 'Class group')

# %%
# alive group
alive = data['alive'].value_counts()
alive
# Out:
# no     549
# yes    342
# Name: alive, dtype: int64

# %%
label=data['alive'].unique()
plt.pie(alive,autopct="%.2f",labels=label)
plt.title("Alive or Died")
# Out:
# Text(0.5, 1.0, 'Alive or Died')

# %%
#fare
sns.distplot(data.fare)
plt.title("Fare")
# Out:
# <ipython-input-14-7c1e531274c4>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.fare)
# Text(0.5, 1.0, 'Fare')

# %%
# sex v/s who
plt.scatter(data['sex'],data['who'])
plt.xlabel('Sex')
plt.ylabel('Who')
plt.title('Sex v/s Who')
# Out:
# Text(0.5, 1.0, 'Sex v/s Who')

# %%
plt.figure(figsize = (20,10))        
sns.heatmap(data.corr(),annot = True)
# Out:
# <ipython-input-19-e9975bf2d0a4>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot = True)
# <Axes: >

# %%
#summary of all the data
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#box plot
plt.boxplot(data['survived'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe626e276d0>,
#   <matplotlib.lines.Line2D at 0x7fe626e27970>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe626e27c10>,
#   <matplotlib.lines.Line2D at 0x7fe626e27eb0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe626e27430>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe626c5c190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe626c5c430>],
#  'means': []}

# %%
#box plot
plt.boxplot(data['pclass'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe626ca2410>,
#   <matplotlib.lines.Line2D at 0x7fe626ca26b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe626ca2950>,
#   <matplotlib.lines.Line2D at 0x7fe626ca2bf0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe626ca2170>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe626ca2e90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe626ca3130>],
#  'means': []}

# %%
#box plot
plt.boxplot(data['sibsp'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe626d1ace0>,
#   <matplotlib.lines.Line2D at 0x7fe626d1af80>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe626d1b220>,
#   <matplotlib.lines.Line2D at 0x7fe626d1b4c0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe626d1aa40>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe626d1b760>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe626d1ba00>],
#  'means': []}

# %%
#box plot
plt.boxplot(data['parch'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe626b8b0d0>,
#   <matplotlib.lines.Line2D at 0x7fe626b8b370>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe626b8b610>,
#   <matplotlib.lines.Line2D at 0x7fe626b8b8b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe626b8ae30>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe626b8bb50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe626b8bdf0>],
#  'means': []}

# %%
#box plot
plt.boxplot(data['fare'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe626c06770>,
#   <matplotlib.lines.Line2D at 0x7fe626c06a10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe626c06cb0>,
#   <matplotlib.lines.Line2D at 0x7fe626c06e60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe626c064d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe626c07100>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe626c073a0>],
#  'means': []}

# %%
data.isna()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# 0    False       False   True        False  False  False
# 1    False       False  False        False  False  False
# 2    False       False   True        False  False  False
# 3    False       False  False        False  False  False
# 4    False       False   True        False  False  False
# ..     ...         ...    ...          ...    ...    ...
# 886  False       False   True        False  False  False
# 887  False       False  False        False  False  False
# 888  False       False   True        False  False  False
# 889  False       False  False        False  False  False
# 890  False       False   True        False  False  False
#
# [891 rows x 15 columns]

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data.isnull().any()
# Out:
# survived       False
# pclass         False
# sex            False
# age             True
# sibsp          False
# parch          False
# fare           False
# embarked        True
# class          False
# who            False
# adult_male     False
# deck            True
# embark_town     True
# alive          False
# alone          False
# dtype: bool

# %%
# to fill age
data['age'].fillna(data['age'].mean(),inplace=True)

# %%
# to fill embarked
data['embarked'].fillna(data['embarked'].mode()[0],inplace=True)

# %%
# to fill deck
data['deck'].fillna(data['deck'].mode()[0],inplace=True)

# %%
# to fill embark_town
data['embark_town'].fillna(data['embark_town'].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True    C  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False    C  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True    C  Southampton    no   True

# %%
data.shape
# Out:
# (891, 15)

# %%
min_threshold=data['fare'].quantile(0.25)
min_threshold
# Out:
# 7.9104

# %%
max_threshold=data['fare'].quantile(0.75)
max_threshold
# Out:
# 31.0

# %%
data[data.fare>max_threshold]
# Out:
#      survived  pclass     sex        age  sibsp  parch      fare embarked  \
# 1           1       1  female  38.000000      1      0   71.2833        C
# 3           1       1  female  35.000000      1      0   53.1000        S
# 6           0       1    male  54.000000      0      0   51.8625        S
# 13          0       3    male  39.000000      1      5   31.2750        S
# 23          1       1    male  28.000000      0      0   35.5000        S
# ..        ...     ...     ...        ...    ...    ...       ...      ...
# 856         1       1  female  45.000000      1      1  164.8667        S
# 863         0       3  female  29.699118      8      2   69.5500        S
# 867         0       1    male  31.000000      0      0   50.4958        S
# 871         1       1  female  47.000000      1      1   52.5542        S
# 879         1       1  female  56.000000      0      1   83.1583        C
#
#      class    who  adult_male deck  embark_town alive  alone
# 1    First  woman       False    C    Cherbourg   yes  False
# 3    First  woman       False    C  Southampton   yes  False
# 6    First    man        True    E  Southampton    no   True
# 13   Third    man        True    C  Southampton    no  False
# 23   First    man        True    A  Southampton   yes   True
# ..     ...    ...         ...  ...          ...   ...    ...
# 856  First  woman       False    C  Southampton   yes  False
# 863  Third  woman       False    C  Southampton    no  False
# 867  First    man        True    A  Southampton    no   True
# 871  First  woman       False    D  Southampton   yes  False
# 879  First  woman       False    C    Cherbourg   yes  False
#
# [222 rows x 15 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True    C  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False    C  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True    C  Southampton    no   True

# %%
#enconding sex
le = LabelEncoder()
data.sex=le.fit_transform(data.sex)
data
# Out:
#      survived  pclass  sex        age  sibsp  parch     fare embarked   class  \
# 0           0       3    1  22.000000      1      0   7.2500        S   Third
# 1           1       1    0  38.000000      1      0  71.2833        C   First
# 2           1       3    0  26.000000      0      0   7.9250        S   Third
# 3           1       1    0  35.000000      1      0  53.1000        S   First
# 4           0       3    1  35.000000      0      0   8.0500        S   Third
# ..        ...     ...  ...        ...    ...    ...      ...      ...     ...
# 886         0       2    1  27.000000      0      0  13.0000        S  Second
# 887         1       1    0  19.000000      0      0  30.0000        S   First
# 888         0       3    0  29.699118      1      2  23.4500        S   Third
# 889         1       1    1  26.000000      0      0  30.0000        C   First
# 890         0       3    1  32.000000      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True    C  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False    C  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True    C  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True    C  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False    C  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True    C   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
#encoding who
data.who=le.fit_transform(data.who)
data
# Out:
#      survived  pclass  sex        age  sibsp  parch     fare embarked   class  \
# 0           0       3    1  22.000000      1      0   7.2500        S   Third
# 1           1       1    0  38.000000      1      0  71.2833        C   First
# 2           1       3    0  26.000000      0      0   7.9250        S   Third
# 3           1       1    0  35.000000      1      0  53.1000        S   First
# 4           0       3    1  35.000000      0      0   8.0500        S   Third
# ..        ...     ...  ...        ...    ...    ...      ...      ...     ...
# 886         0       2    1  27.000000      0      0  13.0000        S  Second
# 887         1       1    0  19.000000      0      0  30.0000        S   First
# 888         0       3    0  29.699118      1      2  23.4500        S   Third
# 889         1       1    1  26.000000      0      0  30.0000        C   First
# 890         0       3    1  32.000000      0      0   7.7500        Q   Third
#
#      who  adult_male deck  embark_town alive  alone
# 0      1        True    C  Southampton    no  False
# 1      2       False    C    Cherbourg   yes  False
# 2      2       False    C  Southampton   yes   True
# 3      2       False    C  Southampton   yes  False
# 4      1        True    C  Southampton    no   True
# ..   ...         ...  ...          ...   ...    ...
# 886    1        True    C  Southampton    no   True
# 887    2       False    B  Southampton   yes   True
# 888    2       False    C  Southampton    no  False
# 889    1        True    C    Cherbourg   yes   True
# 890    1        True    C   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
#encoding embarked
data.embarked=le.fit_transform(data.embarked)
data
# Out:
#      survived  pclass  sex        age  sibsp  parch     fare  embarked  \
# 0           0       3    1  22.000000      1      0   7.2500         2
# 1           1       1    0  38.000000      1      0  71.2833         0
# 2           1       3    0  26.000000      0      0   7.9250         2
# 3           1       1    0  35.000000      1      0  53.1000         2
# 4           0       3    1  35.000000      0      0   8.0500         2
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 886         0       2    1  27.000000      0      0  13.0000         2
# 887         1       1    0  19.000000      0      0  30.0000         2
# 888         0       3    0  29.699118      1      2  23.4500         2
# 889         1       1    1  26.000000      0      0  30.0000         0
# 890         0       3    1  32.000000      0      0   7.7500         1
#
#       class  who  adult_male deck  embark_town alive  alone
# 0     Third    1        True    C  Southampton    no  False
# 1     First    2       False    C    Cherbourg   yes  False
# 2     Third    2       False    C  Southampton   yes   True
# 3     First    2       False    C  Southampton   yes  False
# 4     Third    1        True    C  Southampton    no   True
# ..      ...  ...         ...  ...          ...   ...    ...
# 886  Second    1        True    C  Southampton    no   True
# 887   First    2       False    B  Southampton   yes   True
# 888   Third    2       False    C  Southampton    no  False
# 889   First    1        True    C    Cherbourg   yes   True
# 890   Third    1        True    C   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
#encoding adult_male
data.adult_male=le.fit_transform(data.adult_male)
data
# Out:
#      survived  pclass  sex        age  sibsp  parch     fare  embarked  \
# 0           0       3    1  22.000000      1      0   7.2500         2
# 1           1       1    0  38.000000      1      0  71.2833         0
# 2           1       3    0  26.000000      0      0   7.9250         2
# 3           1       1    0  35.000000      1      0  53.1000         2
# 4           0       3    1  35.000000      0      0   8.0500         2
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 886         0       2    1  27.000000      0      0  13.0000         2
# 887         1       1    0  19.000000      0      0  30.0000         2
# 888         0       3    0  29.699118      1      2  23.4500         2
# 889         1       1    1  26.000000      0      0  30.0000         0
# 890         0       3    1  32.000000      0      0   7.7500         1
#
#       class  who  adult_male deck  embark_town alive  alone
# 0     Third    1           1    C  Southampton    no  False
# 1     First    2           0    C    Cherbourg   yes  False
# 2     Third    2           0    C  Southampton   yes   True
# 3     First    2           0    C  Southampton   yes  False
# 4     Third    1           1    C  Southampton    no   True
# ..      ...  ...         ...  ...          ...   ...    ...
# 886  Second    1           1    C  Southampton    no   True
# 887   First    2           0    B  Southampton   yes   True
# 888   Third    2           0    C  Southampton    no  False
# 889   First    1           1    C    Cherbourg   yes   True
# 890   Third    1           1    C   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
#encoding alive
data.alive=le.fit_transform(data.alive)
data
# Out:
#      survived  pclass  sex        age  sibsp  parch     fare  embarked  \
# 0           0       3    1  22.000000      1      0   7.2500         2
# 1           1       1    0  38.000000      1      0  71.2833         0
# 2           1       3    0  26.000000      0      0   7.9250         2
# 3           1       1    0  35.000000      1      0  53.1000         2
# 4           0       3    1  35.000000      0      0   8.0500         2
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 886         0       2    1  27.000000      0      0  13.0000         2
# 887         1       1    0  19.000000      0      0  30.0000         2
# 888         0       3    0  29.699118      1      2  23.4500         2
# 889         1       1    1  26.000000      0      0  30.0000         0
# 890         0       3    1  32.000000      0      0   7.7500         1
#
#       class  who  adult_male deck  embark_town  alive  alone
# 0     Third    1           1    C  Southampton      0  False
# 1     First    2           0    C    Cherbourg      1  False
# 2     Third    2           0    C  Southampton      1   True
# 3     First    2           0    C  Southampton      1  False
# 4     Third    1           1    C  Southampton      0   True
# ..      ...  ...         ...  ...          ...    ...    ...
# 886  Second    1           1    C  Southampton      0   True
# 887   First    2           0    B  Southampton      1   True
# 888   Third    2           0    C  Southampton      0  False
# 889   First    1           1    C    Cherbourg      1   True
# 890   Third    1           1    C   Queenstown      0   True
#
# [891 rows x 15 columns]

# %%
X=data.iloc[:,0:13]
X.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class  who  \
# 0         0       3    1  22.0      1      0   7.2500         2  Third    1
# 1         1       1    0  38.0      1      0  71.2833         0  First    2
# 2         1       3    0  26.0      0      0   7.9250         2  Third    2
# 3         1       1    0  35.0      1      0  53.1000         2  First    2
# 4         0       3    1  35.0      0      0   8.0500         2  Third    1
#
#    adult_male deck  embark_town
# 0           1    C  Southampton
# 1           0    C    Cherbourg
# 2           0    C  Southampton
# 3           0    C  Southampton
# 4           1    C  Southampton

# %%
Y=data.iloc[:,13:]
Y.head()
# Out:
#    alive  alone
# 0      0  False
# 1      1  False
# 2      1   True
# 3      1  False
# 4      0   True
